# %%
# Diagnóstico: Verificar ruta y archivos en datasets antes de crear el DatasetManager
import os
ruta_datasets = os.path.abspath(os.path.join(os.path.dirname("../src/dataset_manager.py"), '../datasets/'))
print("Ruta datasets:", ruta_datasets)
print("Archivos en datasets:", os.listdir(ruta_datasets))
# Out:
# Ruta datasets: c:\MAESTRIA UNI\TERCER CICLO\PROYECTO DE INVESTIGACION 1\DemoSprint1\DemoSprint1Final\datasets
# Archivos en datasets: ['clientes.json', 'empleados.json', 'productos.json', 'splits.json', 'transactions_collection.json', 'usuarios.json', 'ventas.json']

# %%
# Refuerzo: agregar 'dateMascara' y asegurar sinónimos para 'Date' en el schema de 'header'
import sys
sys.path.append('..')
sys.path.append('../src')
from dataset_manager import create_default_dataset, FieldDefinition
manager = create_default_dataset()

# Asegura que el schema 'header' exista antes de agregar campos
if 'header' not in manager.schemas:
    manager.create_schema('header', 'Colección de encabezados de ejemplo')

# Asegura que el campo 'date' exista en el schema 'header' antes de modificar sinónimos
if 'date' not in manager.schemas['header'].fields:
    manager.add_field('header', FieldDefinition(name='date', type='string', path='date', description='Fecha en formato ISO', examples=['2023-11-11T10:00:00'], synonyms=['Date', 'fecha']))

# Agregar campo 'dateMascara' (tipo string, resultado esperado de la proyección)
manager.add_field('header', FieldDefinition(name='dateMascara', type='string', path='dateMascara', description='Fecha en formato %Y%m%d', examples=['20251111'], synonyms=['date_mascara']))
# Refuerza sinónimos para 'Date' en el campo 'date'
if 'date' in manager.schemas['header'].fields:
    manager.schemas['header'].fields['date'].synonyms = list(set(manager.schemas['header'].fields['date'].synonyms + ['Date', 'date']))

print('Campos actuales en header:', list(manager.schemas['header'].fields.keys()))
if 'date' in manager.schemas['header'].fields:
    print('Sinónimos de date:', manager.schemas['header'].fields['date'].synonyms)
else:
    print("El campo 'date' no existe en el schema 'header'.")
# Out:
# Campos actuales en header: ['date', 'dateMascara']
# Sinónimos de date: ['fecha', 'date', 'Date']

# %% [markdown]
# # Agente Inteligente para la Generación Automática de Queries MongoDB a partir de Lenguaje Natural
#
# Este notebook demuestra el uso de un agente inteligente capaz de transformar instrucciones en lenguaje natural en queries MongoDB, incluyendo soporte para joins dinámicos.

# %%
# Si tienes problemas de compatibilidad, ejecuta también esta celda para forzar la versión correcta de pydantic-core.
# !pip install --force-reinstall --no-deps pydantic_core==2.41.1
# !pip install --upgrade pydantic openai
# Out:
# ^C
# Collecting pydantic_core==2.41.1
#   Downloading pydantic_core-2.41.1-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Downloading pydantic_core-2.41.1-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 6.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.5 MB/s  0:00:00
# Installing collected packages: pydantic_core
#   Attempting uninstall: pydantic_core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
# Successfully installed pydantic_core-2.41.5
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\antho\AppData\Local\Programs\Python\Python311\Lib\site-packages\~ydantic_core'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\antho\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pydantic in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (2.12.3)
# Collecting pydantic
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Requirement already satisfied: openai in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (2.6.1)
# Collecting openai
#   Downloading openai-2.7.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from pydantic) (0.7.0)
# Collecting pydantic-core==2.41.5 (from pydantic)
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: colorama in c:\users\antho\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.1 MB/s  0:00:00
# Downloading openai-2.7.2-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 4.8 MB/s  0:00:00
# Installing collected packages: pydantic-core, pydantic, openai
#
#   Attempting uninstall: pydantic-core
#
#     Found existing installation: pydantic_core 2.41.1
#
#     Uninstalling pydantic_core-2.41.1:
#
#       Successfully uninstalled pydantic_core-2.41.1
#
#   Attempting uninstall: pydantic
#
#     Found existing installation: pydantic 2.12.3
#
#     Uninstalling pydantic-2.12.3:
#
#       Successfully uninstalled pydantic-2.12.3
#
#    ------------- -------------------------- 1/3 [pydantic]
#    ------------- -------------------------- 1/3 [pydantic]
#   Attempting uninstall: openai
#    ------------- -------------------------- 1/3 [pydantic]
#     Found existing installation: openai 2.6.1
#    ------------- -------------------------- 1/3 [pydantic]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#     Uninstalling openai-2.6.1:
#    -------------------------- ------------- 2/3 [openai]
#       Successfully uninstalled openai-2.6.1
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    -------------------------- ------------- 2/3 [openai]
#    ---------------------------------------- 3/3 [openai]
#
# Successfully installed openai-2.7.2 pydantic-2.12.4 pydantic-core-2.41.5
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
#     WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\antho\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\antho\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
sys.path.append('..')
sys.path.append('../src')
import importlib
import AgenteGeneradorQueryMongo
importlib.reload(AgenteGeneradorQueryMongo)
from AgenteGeneradorQueryMongo import SmartMongoQueryGenerator
from dataset_manager import create_default_dataset
manager = create_default_dataset()
generator = SmartMongoQueryGenerator(dataset_manager=manager)
# Ejemplo de instrucción en lenguaje natural para JOIN (proyección dinámica de campos del join)
instruccion_join = "une la colección empleados con la colección departamentos usando el campo departamento_id proyecta los campos nombre, apellido, departamentos_info, departamento_nombre"
query_join = generator.generate_query('empleados', instruccion_join)
print('Query generada para join:')
print(query_join)
# Out:
# WARNING:root:[WARNING] Colección origen o destino no existe en el dataset: empleados, departamentos. Se generará el pipeline igualmente.
# WARNING:root:[WARNING] Campo de unión 'departamento_id' no existe en ambas colecciones: empleados, departamentos. Se generará el pipeline igualmente.
# WARNING:root:[WARNING] Campo de unión 'departamento_id' no existe en ambas colecciones: empleados, departamentos. Se generará el pipeline igualmente.
# Query generada para join:
# [{'$group': {'_id': '$departamento', 'empleados': {'$sum': 1}}}, {'$project': {'departamento': '$_id', 'empleados': 1, '_id': 0}}]

# %% [markdown]
# Puedes modificar la variable `instruccion` para probar otras frases en lenguaje natural, incluyendo joins con diferentes nombres de colección y campo, o instrucciones que no requieran join.

# %%
# Ejemplo 1: filtra registros cuyo Devices.ServicePoints.ShipOutCycles.Transactions.Total sea mayor a 3000
instruccion = "filtra registros cuyo Total sea mayor a 3000"
query = generator.generate_query('transacciones', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
# Mostrar el pipeline como JSON legible si es una lista o dict
import json
if isinstance(query, (list, dict)):
    print("\nPipeline generado (formato JSON):")
    print(json.dumps(query, indent=2, ensure_ascii=False))
else:
    print("\nPipeline generado:")
    print(query)
# Out:
# [DEBUG] Pipeline generado: {'$match': {'Devices.ServicePoints.ShipOutCycles.Transactions.Total': {'$gt': 3000.0}}}
# Instrucción: filtra registros cuyo Total sea mayor a 3000
# Query generado:
# [{'$match': {'Devices.ServicePoints.ShipOutCycles.Transactions.Total': {'$gt': 3000.0}}}]
#
# Pipeline generado (formato JSON):
# [
#   {
#     "$match": {
#       "Devices.ServicePoints.ShipOutCycles.Transactions.Total": {
#         "$gt": 3000.0
#       }
#     }
#   }
# ]

# %%
# Ejemplo 2: muestra los nombres y apellidos de los empleados del departamento de ventas
instruccion = "muestra los nombres y apellidos de los empleados del departamento de ventas"
query = generator.generate_query('empleados', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: muestra los nombres y apellidos de los empleados del departamento de ventas
# Query generado:
# [{'$group': {'_id': '$departamento', 'empleados': {'$sum': 1}}}, {'$project': {'departamento': '$_id', 'empleados': 1, '_id': 0}}]

# %%
# Ejemplo 3: cuenta cuántos empleados hay en cada departamento
instruccion = "cuenta cuántos empleados hay en cada departamento"
query = generator.generate_query('empleados', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: cuenta cuántos empleados hay en cada departamento
# Query generado:
# [{'$group': {'_id': '$departamento', 'empleados': {'$sum': 1}}}, {'$project': {'departamento': '$_id', 'empleados': 1, '_id': 0}}]

# %%
# Ejemplo 4: ordena los empleados por fecha de ingreso descendente
instruccion = "ordena los empleados por fecha de ingreso descendente"
query = generator.generate_query('empleados', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: ordena los empleados por fecha de ingreso descendente
# Query generado:
# [{'$sort': {'fecha_venta': -1}}]

# %%
# Ejemplo 5: busca empleados cuyo nombre comience con 'A'
instruccion = "busca empleados cuyo nombre comience con 'A'"
query = generator.generate_query('empleados', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: busca empleados cuyo nombre comience con 'A'
# Query generado:
# [{'$match': {'nombre': {'$regex': '^A', '$options': 'i'}}}]

# %%
# Ejemplo 6: filtra transacciones realizadas entre 2023-01-01 y 2023-01-31
instruccion = "filtra transacciones realizadas entre 2023-01-01 y 2023-01-31"
query = generator.generate_query('transacciones', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: filtra transacciones realizadas entre 2023-01-01 y 2023-01-31
# Query generado:
# [{'$match': {'Date': {'$gte': '2023-01-01', '$lte': '2023-01-31'}}}, {'$unwind': '$Devices'}, {'$unwind': '$Devices.ServicePoints'}, {'$unwind': '$Devices.ServicePoints.ShipOutCycles'}, {'$unwind': '$Devices.ServicePoints.ShipOutCycles.Transactions'}]

# %%
# Ejemplo 7: muestra los 5 productos más vendidos
instruccion = "muestra los 5 productos más vendidos"
query = generator.generate_query('productos', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: muestra los 5 productos más vendidos
# Query generado:
# [{'$group': {'_id': '$item', 'total_ventas': {'$sum': '$total_venta'}}}, {'$sort': {'total_ventas': -1}}, {'$limit': 5}, {'$project': {'productos': '$_id', 'total_ventas': 1, '_id': 0}}]

# %%
# Ejemplo 8: agrega la suma total de ventas por mes
instruccion = "agrega la suma total de ventas por mes"
query = generator.generate_query('ventas', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: agrega la suma total de ventas por mes
# Query generado:
# [{'$addFields': {'anio_mes': {'$substr': ['$fecha_venta', 0, 7]}}}, {'$group': {'_id': '$anio_mes', 'suma_total_ventas': {'$sum': '$total_venta'}}}, {'$sort': {'_id': 1}}, {'$project': {'mes': '$_id', 'suma_total_ventas': 1, '_id': 0}}]

# %%
# Ejemplo 9: une la colección ventas con clientes usando cliente_id y proyecta nombre_cliente y total_venta
instruccion = "une la colección ventas con clientes usando cliente_id y proyecta nombre_cliente y total_venta"
query = generator.generate_query('ventas', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: une la colección ventas con clientes usando cliente_id y proyecta nombre_cliente y total_venta
# Query generado:
# [{'$lookup': {'from': 'clientes', 'localField': 'cliente_id', 'foreignField': 'cliente_id', 'as': 'clientes_info'}}, {'$unwind': '$clientes_info'}, {'$project': {'nombre_cliente': 1, 'total_venta': 1}}]

# %%
#Ejemplo 10: filtra clientes que no hayan realizado compras en el último año
instruccion = "filtra clientes que no hayan realizado compras en el penultimo año"
query = generator.generate_query('clientes', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# Instrucción: filtra clientes que no hayan realizado compras en el penultimo año
# Query generado:
# [{'$match': {'categoria': {'$not': {'$elemMatch': {'Date': {'$gte': '2023-11-14', '$lt': '2024-11-13'}}}}}}]

# %%
instruccion = "une la colección empleados con la colección departamentos usando el campo departamento_id"
query = generator.generate_query('empleados', instruccion)
print(f"Instrucción: {instruccion}")
print("Query generado:")
print(query)
print()
# Out:
# WARNING:root:[WARNING] Colección origen o destino no existe en el dataset: empleados, departamentos. Se generará el pipeline igualmente.
# WARNING:root:[WARNING] Campo de unión 'departamento_id' no existe en ambas colecciones: empleados, departamentos. Se generará el pipeline igualmente.
# WARNING:root:[WARNING] Campo de unión 'departamento_id' no existe en ambas colecciones: empleados, departamentos. Se generará el pipeline igualmente.
# Instrucción: une la colección empleados con la colección departamentos usando el campo departamento_id
# Query generado:
# [{'$group': {'_id': '$departamento', 'empleados': {'$sum': 1}}}, {'$project': {'departamento': '$_id', 'empleados': 1, '_id': 0}}]

# %%
# Caso 1: Header simple
instruccion_header = """
crear campo dateMascara que convierta el campo Date a formato %Y%m%d usando los primeros 19 caracteres
crear campo reg que concatene: "1", "002", el campo Date convertido a formato %Y%m%d%H%M%S usando los primeros 19 caracteres, "00", "01", un espacio, un salto de línea, otro salto de línea
"""
print('--- Caso 1: Header ---')
query_header = generator.generate_query('header', instruccion_header)
print(query_header)
# Out:
# --- Caso 1: Header ---
# [{'$project': {}}, {'$addFields': {'dateMascara': {'$substr': ['$date', 0, 8]}, 'reg': {'$concat': ['1', '002', {'$substr': ['$date', 0, 14]}, '00', '01', ' ', '\n', '\n']}}}]

# %% [markdown]
# # Ejemplos avanzados de instrucciones en lenguaje natural
# A continuación se muestran tres casos de uso para probar el agente generador de queries MongoDB:

# %%
# Caso 2: Detalle avanzado
instruccion_detalle = """
desanidar Devices
desanidar Devices.ServicePoints
desanidar Devices.ServicePoints.ShipOutCycles
desanidar Devices.ServicePoints.ShipOutCycles.Transactions
agrupar por date, deviceId, branchCode, subChannelCode, shipOutCode, currencyCode, confirmationCode y sumar el total de Devices.ServicePoints.ShipOutCycles.Transactions.Total
proyectar los caracteres de la posición 2 en adelante del deviceId
crear campo confirmationCode que sea _id.confirmationCode o " " si es nulo
crear campo totalParteEntera que sea el primer elemento del split del total por punto
crear campo totalParteDecimal que sea el segundo elemento del split del total por punto o "00" si es nulo
crear campo reg que sea la concatenación de "5", la condición de moneda, la fecha, "00", el deviceId con padding, el shipOutCode con padding, la condición de sucursal, el monto con padding y el código de confirmación con padding
ordenar por deviceId y shipOutCode y subChannelCode y currencyCode
"""
print('--- Caso 2: Detalle ---')
query_detalle = generator.generate_query('detalle', instruccion_detalle)
print(query_detalle)
# Out:
# --- Caso 2: Detalle ---
# [{'$project': {'deviceId': {'$substrBytes': ['$deviceId', 1, {'$strLenBytes': '$deviceId'}]}}}, {'$addFields': {'reg': {'$concat': ['1', '002', {'$substr': ['$date', 0, 14]}, '00', '01', ' ', '\n', '\n']}}}]

# %%
# Caso 3: Detalle con agrupaciones y padding
instruccion_detalle2 = """
desanidar Devices
desanidar Devices.ServicePoints
desanidar Devices.ServicePoints.ShipOutCycles con preserveNullAndEmptyArrays
desanidar Devices.ServicePoints.ShipOutCycles.Transactions con preserveNullAndEmptyArrays
agrupar por deviceId, branchCode, subChannelCode, shipOutCode, currencyCode y sumar el total de Devices.ServicePoints.ShipOutCycles.Transactions.Total en soles y en dólares según el código de moneda
luego agrupa todo y suma totalSoles y totalDolares, y cuenta total de registros en soles y en dólares según el código de moneda
crear campo totalParteEnteraSoles que sea el primer elemento del split de totalSoles por punto
crear campo totalParteDecimalSoles que sea el segundo elemento del split de totalSoles por punto o "00" si es nulo
crear campo totalParteEnteraDolares que sea el primer elemento del split de totalDolares por punto
crear campo totalParteDecimalDolares que sea el segundo elemento del split de totalDolares por punto o "00" si es nulo
crear campo reg que concatene: "9", el total de registros con padding, el total de registros en soles con padding, el total de registros en dólares con padding, el monto en soles con padding, el monto en dólares con padding, un salto de línea, otro salto de línea
"""
print('--- Caso 3: Detalle agrupado ---')
query_detalle2 = generator.generate_query('detalle2', instruccion_detalle2)
print(query_detalle2)
# Out:
# --- Caso 3: Detalle agrupado ---
# [{'$group': {'_id': None, 'sumaTotalSoles': {'$sum': '$totalSoles'}, 'sumaTotalDolares': {'$sum': '$totalDolares'}, 'conteoSoles': {'$sum': {'$cond': [{'$eq': ['$currencyCode', 'PEN']}, 1, 0]}}, 'conteoDolares': {'$sum': {'$cond': [{'$eq': ['$currencyCode', 'USD']}, 1, 0]}}}}]

# %%
# Diagnóstico: Verificar colecciones cargadas en el DatasetManager
print("Colecciones cargadas:", list(manager.schemas.keys()))
for coll in manager.schemas:
    print(f"\nColección: {coll}")
    print("Campos:", list(manager.schemas[coll].fields.keys()))
    print("Ejemplo de documento:", manager.schemas[coll].sample_documents[0] if manager.schemas[coll].sample_documents else "Sin ejemplos")
# Out:
# Colecciones cargadas: ['empleados', 'productos', 'transactions_collection', 'ventas', 'clientes']
#
# Colección: empleados
# Campos: ['empleado_id', 'nombre', 'apellido', 'departamento']
# Ejemplo de documento: {'_id': 201, 'empleado_id': 201, 'nombre': 'Carlos', 'apellido': 'Ramírez', 'departamento': 'Ventas'}
#
# Colección: productos
# Campos: ['item', 'categoria', 'precio']
# Ejemplo de documento: {'_id': 1, 'item': 'Laptop', 'categoria': 'Electrónica', 'precio': 1200}
#
# Colección: transactions_collection
# Campos: ['Date', 'deviceId', 'BranchCode', 'ServicePoints', 'ShipOutCycles', 'Transactions', 'Total', 'CurrencyCode', 'SubChannelCode', 'Code', 'ConfirmationCode']
# Ejemplo de documento: {'Date': '2024-01-15T10:30:00Z', 'Devices': [{'Id': 'DEV001', 'BranchCode': 'PE240', 'ServicePoints': [{'ShipOutCycles': [{'SubChannelCode': 'CH001', 'Code': 'SO001', 'ConfirmationCode': 'CONF001', 'Transactions': [{'Total': 100.5, 'CurrencyCode': 'PEN'}]}]}]}]}
#
# Colección: ventas
# Campos: ['cliente_id', 'total_venta', 'fecha_venta', 'categoria_producto', 'producto']
# Ejemplo de documento: {'_id': 1, 'cliente_id': 101, 'total_venta': 500, 'fecha_venta': '2025-11-01', 'categoria_producto': 'Electrónica', 'producto': 'Laptop'}
#
# Colección: clientes
# Campos: ['cliente_id', 'nombre_cliente']
# Ejemplo de documento: {'_id': 101, 'cliente_id': 101, 'nombre_cliente': 'Juan'}

# %%
# Agregar campos 'date' y 'fechaformateada' al schema de la colección 'header' para pruebas de proyección de fecha
from dataset_manager import FieldDefinition

if 'header' not in manager.schemas:
    manager.create_schema('header', 'Colección de encabezados de ejemplo')

# Agregar campo 'date' (tipo string, ejemplo de fecha ISO)
manager.add_field('header', FieldDefinition(name='date', type='string', path='date', description='Fecha en formato ISO', examples=['2023-11-11T10:00:00'], synonyms=['Date', 'fecha']))
# Agregar campo 'fechaformateada' (tipo string, resultado esperado de la proyección)
manager.add_field('header', FieldDefinition(name='fechaformateada', type='string', path='fechaformateada', description='Fecha formateada', examples=['2023-11-11'], synonyms=['fecha_formateada']))
# Agregar un documento de ejemplo
manager.add_sample_document('header', {'_id': 1, 'date': '2023-11-11T10:00:00'})

print('Campos agregados al schema de header:', list(manager.schemas['header'].fields.keys()))
print('Ejemplo de documento:', manager.schemas['header'].sample_documents[0])
# Out:
# Campos agregados al schema de header: ['date', 'fechaformateada']
# Ejemplo de documento: {'_id': 1, 'date': '2023-11-11T10:00:00'}
